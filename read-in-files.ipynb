# %%
import pandas as pd

sb_airport_data = pd.read_csv('sb-airport.csv')

type(sb_airport_data)
# Out:
# pandas.core.frame.DataFrame

# %%
sb_airport_data.iloc[285]
# Out:
# STATION                                       USW00023190
# NAME               SANTA BARBARA MUNICIPAL AIRPORT, CA US
# LATITUDE                                          34.4258
# LONGITUDE                                       -119.8425
# ELEVATION                                             2.7
# DATE                                           2021-10-13
# AWND                                                  NaN
# AWND_ATTRIBUTES                                       NaN
# PRCP                                                  0.0
# PRCP_ATTRIBUTES                                  ,,D,2400
# TAVG                                                  NaN
# TAVG_ATTRIBUTES                                       NaN
# TMAX                                                   69
# TMAX_ATTRIBUTES                                       ,,D
# TMIN                                                   44
# TMIN_ATTRIBUTES                                       ,,D
# ...

# %%
sb_airport_data.tail() # default is 6 rows, put in number to specify number of rows to display
# Out:
#          STATION                                    NAME  LATITUDE  LONGITUDE  \
# 281  USW00023190  SANTA BARBARA MUNICIPAL AIRPORT, CA US   34.4258  -119.8425
# 282  USW00023190  SANTA BARBARA MUNICIPAL AIRPORT, CA US   34.4258  -119.8425
# 283  USW00023190  SANTA BARBARA MUNICIPAL AIRPORT, CA US   34.4258  -119.8425
# 284  USW00023190  SANTA BARBARA MUNICIPAL AIRPORT, CA US   34.4258  -119.8425
# 285  USW00023190  SANTA BARBARA MUNICIPAL AIRPORT, CA US   34.4258  -119.8425
#
#      ELEVATION        DATE   AWND AWND_ATTRIBUTES  PRCP PRCP_ATTRIBUTES  ...  \
# 281        2.7  2021-10-09   4.03             ,,W   0.0        ,,D,2400  ...
# 282        2.7  2021-10-10   3.13             ,,W   0.0        ,,D,2400  ...
# 283        2.7  2021-10-11  12.30             ,,W   0.0        ,,D,2400  ...
# 284        2.7  2021-10-12   8.05             ,,W   0.0        ,,D,2400  ...
# 285        2.7  2021-10-13    NaN             NaN   0.0        ,,D,2400  ...
#
# ...

# %%
sb_airport_data.columns # attribute of a dataframe, not a function
# Out:
# Index(['STATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'DATE', 'AWND',
#        'AWND_ATTRIBUTES', 'PRCP', 'PRCP_ATTRIBUTES', 'TAVG', 'TAVG_ATTRIBUTES',
#        'TMAX', 'TMAX_ATTRIBUTES', 'TMIN', 'TMIN_ATTRIBUTES', 'WDF2',
#        'WDF2_ATTRIBUTES', 'WDF5', 'WDF5_ATTRIBUTES', 'WSF2', 'WSF2_ATTRIBUTES',
#        'WSF5', 'WSF5_ATTRIBUTES', 'WT01', 'WT01_ATTRIBUTES', 'WT02',
#        'WT02_ATTRIBUTES', 'WT03', 'WT03_ATTRIBUTES', 'WT05', 'WT05_ATTRIBUTES',
#        'WT08', 'WT08_ATTRIBUTES'],
#       dtype='object')
